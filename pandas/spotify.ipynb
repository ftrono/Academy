# %% [markdown]
# ## Spotify Top 2017

# %%
import pandas as pd
import numpy as np

# %%
ranking = pd.read_csv("../Dataset/Spotify/spotify-worldwide-daily-song-ranking.csv")
ranking.tail(20)
# Out:
#          Position                              Track Name              Artist  \
# 3441177       181  Pretty Girl - Cheat Codes X CADE Remix    Maggie Lindemann
# 3441178       182                                      心淡           Joey Yung
# 3441179       183                Friends (with BloodPop®)       Justin Bieber
# 3441180       184                                    高山低谷            Phil Lam
# 3441181       185                                    死亡之吻         Kelvin Kwan
# 3441182       186                                      無賴        Ronald Cheng
# 3441183       187                                   月球下的人             Gin Lee
# 3441184       188                                 Gashina               SUNMI
# 3441185       189                                      七友        Edmond Leung
# 3441186       190                                 那一年零一個月         Feanna Wong
# 3441187       191           我多喜歡你,你會知道 - 網劇《致我們單純的小美好》推廣曲                 王俊琪
# ...

# %%
len(ranking['Track Name'].unique().tolist())
# Out:
# 18598

# %%
ranking.query("Region == 'us'").to_csv("../out/spotify_ranking_2017.csv", index=False)
